# %% [markdown]
# <a href="https://colab.research.google.com/github/UtkarshGupta048/Data-Analytics/blob/main/Loan_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-462c8d5e-d5a4-4b58-9607-daffabe8b89c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-462c8d5e-d5a4-4b58-9607-daffabe8b89c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv(r"loan_test.csv")

# %%
df.head(5)
# Out:
#   Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0   Male     Yes          0      Graduate            No            572000
# 1   Male     Yes          1      Graduate            No            307600
# 2   Male     Yes          2      Graduate            No            500000
# 3   Male     Yes          2      Graduate            No            234000
# 4   Male      No          0  Not Graduate            No            327600
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History   Area
# 0                   0     11000000  360.0             1.0  Urban
# 1              150000     12600000  360.0             1.0  Urban
# 2              180000     20800000  360.0             1.0  Urban
# 3              254600     10000000  360.0             NaN  Urban
# 4                   0      7800000  360.0             1.0  Urban

# %%
df.shape
# Out:
# (367, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Gender              356 non-null    object
#  1   Married             367 non-null    object
#  2   Dependents          357 non-null    object
#  3   Education           367 non-null    object
#  4   Self_Employed       344 non-null    object
#  5   Applicant_Income    367 non-null    int64
#  6   Coapplicant_Income  367 non-null    int64
#  7   Loan_Amount         367 non-null    int64
#  8   Term                361 non-null    float64
#  9   Credit_History      338 non-null    float64
#  10  Area                367 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 31.7+ KB

# %%
df.head(5)
# Out:
#   Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0   Male     Yes          0      Graduate            No            572000
# 1   Male     Yes          1      Graduate            No            307600
# 2   Male     Yes          2      Graduate            No            500000
# 3   Male     Yes          2      Graduate            No            234000
# 4   Male      No          0  Not Graduate            No            327600
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History   Area
# 0                   0     11000000  360.0             1.0  Urban
# 1              150000     12600000  360.0             1.0  Urban
# 2              180000     20800000  360.0             1.0  Urban
# 3              254600     10000000  360.0             NaN  Urban
# 4                   0      7800000  360.0             1.0  Urban

# %%
df.isnull().sum()
# Out:
# Gender                11
# Married                0
# Dependents            10
# Education              0
# Self_Employed         23
# Applicant_Income       0
# Coapplicant_Income     0
# Loan_Amount            0
# Term                   6
# Credit_History        29
# Area                   0
# dtype: int64

# %%
(df.isnull().sum()/df.shape[0])*100      # Percentage Null Values
# Out:
# Gender                2.997275
# Married               0.000000
# Dependents            2.724796
# Education             0.000000
# Self_Employed         6.267030
# Applicant_Income      0.000000
# Coapplicant_Income    0.000000
# Loan_Amount           0.000000
# Term                  1.634877
# Credit_History        7.901907
# Area                  0.000000
# dtype: float64

# %%
df.head(2)
# Out:
#   Gender Married Dependents Education Self_Employed  Applicant_Income  \
# 0   Male     Yes          0  Graduate            No            572000
# 1   Male     Yes          1  Graduate            No            307600
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History   Area
# 0                   0     11000000  360.0             1.0  Urban
# 1              150000     12600000  360.0             1.0  Urban

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
# Fill Categorical data Values by Mode

# %%
df.select_dtypes(include=object).columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Area'],
#       dtype='object')

# %%
# for i in df.select_dtypes(include=object).columns:
#   df[i]=df[i].fillna(df[i].mode()[0])

# %%
df.select_dtypes(include=object).columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Area'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0    Male     Yes          0      Graduate            No            572000
# 1    Male     Yes          1      Graduate            No            307600
# 2    Male     Yes          2      Graduate            No            500000
# 3    Male     Yes          2      Graduate            No            234000
# 4    Male      No          0  Not Graduate            No            327600
# 5    Male     Yes          0  Not Graduate           Yes            216500
# 6  Female      No          1  Not Graduate            No            222600
# 7    Male     Yes          2  Not Graduate            No            388100
# 8    Male     Yes          2      Graduate           NaN           1363300
# 9    Male      No          0  Not Graduate            No            240000
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History       Area
# 0                   0     11000000  360.0             1.0      Urban
# ...

# %%
for i in ['Gender','Dependents','Self_Employed','Term','Credit_History']:
  df[i]=df[i].fillna(df[i].mode()[0])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Gender              367 non-null    object
#  1   Married             367 non-null    object
#  2   Dependents          367 non-null    object
#  3   Education           367 non-null    object
#  4   Self_Employed       367 non-null    object
#  5   Applicant_Income    367 non-null    int64
#  6   Coapplicant_Income  367 non-null    int64
#  7   Loan_Amount         367 non-null    int64
#  8   Term                367 non-null    float64
#  9   Credit_History      367 non-null    float64
#  10  Area                367 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 31.7+ KB

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **Encoding-------**

# %%
en_data=df[['Gender','Married']]
en_data
# Out:
#     Gender Married
# 0     Male     Yes
# 1     Male     Yes
# 2     Male     Yes
# 3     Male     Yes
# 4     Male      No
# ..     ...     ...
# 362   Male     Yes
# 363   Male     Yes
# 364   Male      No
# 365   Male     Yes
# 366   Male      No
#
# [367 rows x 2 columns]

# %%
pd.get_dummies(en_data)
# Out:
#      Gender_Female  Gender_Male  Married_No  Married_Yes
# 0            False         True       False         True
# 1            False         True       False         True
# 2            False         True       False         True
# 3            False         True       False         True
# 4            False         True        True        False
# ..             ...          ...         ...          ...
# 362          False         True       False         True
# 363          False         True       False         True
# 364          False         True        True        False
# 365          False         True       False         True
# 366          False         True        True        False
#
# [367 rows x 4 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder(drop="first")

# %%
ar=ohe.fit_transform(en_data).toarray()

# %%
# pd.DataFrame(ar,columns=["Gender_Female","Gender_Male","Married_No","Married_Yes"])

# %%
# pd.DataFrame(ar,columns=["Gender_Male","Married_Yes"])

# %%
# df

# %%
# pd.DataFrame(df)

# %% [markdown]
# **LAbel Encoder**

# %%
fd=pd.DataFrame({"name":["wscube","cow","cat","dog","black"]})
fd
# Out:
#      name
# 0  wscube
# 1     cow
# 2     cat
# 3     dog
# 4   black

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
fd["en_name"]=le.fit_transform(fd["name"])

# %%
fd
# Out:
#      name  en_name
# 0  wscube        4
# 1     cow        2
# 2     cat        1
# 3     dog        3
# 4   black        0

# %% [markdown]
# **Ordinal Encoding**

# %%
df.head(5)
# Out:
#   Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0   Male     Yes          0      Graduate            No            572000
# 1   Male     Yes          1      Graduate            No            307600
# 2   Male     Yes          2      Graduate            No            500000
# 3   Male     Yes          2      Graduate            No            234000
# 4   Male      No          0  Not Graduate            No            327600
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History   Area
# 0                   0     11000000  360.0             1.0  Urban
# 1              150000     12600000  360.0             1.0  Urban
# 2              180000     20800000  360.0             1.0  Urban
# 3              254600     10000000  360.0             1.0  Urban
# 4                   0      7800000  360.0             1.0  Urban

# %%
df["Area"].unique()
# Out:
# array(['Urban', 'Semiurban', 'Rural'], dtype=object)

# %%
# ord_data=[['Urban', 'Semiurban', 'Rural']]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
# ord_data=[['Urban'], ['Semiurban'], ['Rural']]
area_categories=[['Urban', 'Semiurban', 'Rural']]
oe=OrdinalEncoder(categories=area_categories)
df["Area_Encoder"]=oe.fit_transform(df[['Area']]).astype(int)
df
# Out:
#     Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0     Male     Yes          0      Graduate            No            572000
# 1     Male     Yes          1      Graduate            No            307600
# 2     Male     Yes          2      Graduate            No            500000
# 3     Male     Yes          2      Graduate            No            234000
# 4     Male      No          0  Not Graduate            No            327600
# ..     ...     ...        ...           ...           ...               ...
# 362   Male     Yes         3+  Not Graduate           Yes            400900
# 363   Male     Yes          0      Graduate            No            415800
# 364   Male      No          0      Graduate            No            325000
# 365   Male     Yes          0      Graduate            No            500000
# 366   Male      No          0      Graduate           Yes            920000
#
# ...

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
edu_categories=[['Graduate', 'Not Graduate']]
oe_edu=OrdinalEncoder(categories=edu_categories)
df['Education_Encoder']=oe_edu.fit_transform(df[['Education']]).astype(int)
df
# Out:
#     Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0     Male     Yes          0      Graduate            No            572000
# 1     Male     Yes          1      Graduate            No            307600
# 2     Male     Yes          2      Graduate            No            500000
# 3     Male     Yes          2      Graduate            No            234000
# 4     Male      No          0  Not Graduate            No            327600
# ..     ...     ...        ...           ...           ...               ...
# 362   Male     Yes         3+  Not Graduate           Yes            400900
# 363   Male     Yes          0      Graduate            No            415800
# 364   Male      No          0      Graduate            No            325000
# 365   Male     Yes          0      Graduate            No            500000
# 366   Male      No          0      Graduate           Yes            920000
#
# ...

# %%
cols=list(df.columns)

# %%
cols.remove('Education_Encoder')
edu_index=cols.index('Education')
cols.insert(edu_index+1,'Education_Encoder')
df=df[cols]

# %%
df
# Out:
#     Gender Married Dependents     Education  Education_Encoder Self_Employed  \
# 0     Male     Yes          0      Graduate                  0            No
# 1     Male     Yes          1      Graduate                  0            No
# 2     Male     Yes          2      Graduate                  0            No
# 3     Male     Yes          2      Graduate                  0            No
# 4     Male      No          0  Not Graduate                  1            No
# ..     ...     ...        ...           ...                ...           ...
# 362   Male     Yes         3+  Not Graduate                  1           Yes
# 363   Male     Yes          0      Graduate                  0            No
# 364   Male      No          0      Graduate                  0            No
# 365   Male     Yes          0      Graduate                  0            No
# 366   Male      No          0      Graduate                  0           Yes
#
# ...

# %% [markdown]
# **IQR -  OUTLIERS**

# %% [markdown]
# IRQ = Q3-QI
#
# MIN= Q1 - (1.5*IQR)
#
# MAX= Q2 + (1.5*IQR)

# %%
df.head(5)
# Out:
#   Gender Married Dependents     Education  Education_Encoder Self_Employed  \
# 0   Male     Yes          0      Graduate                  0            No
# 1   Male     Yes          1      Graduate                  0            No
# 2   Male     Yes          2      Graduate                  0            No
# 3   Male     Yes          2      Graduate                  0            No
# 4   Male      No          0  Not Graduate                  1            No
#
#    Applicant_Income  Coapplicant_Income  Loan_Amount   Term  Credit_History  \
# 0            572000                   0     11000000  360.0             1.0
# 1            307600              150000     12600000  360.0             1.0
# 2            500000              180000     20800000  360.0             1.0
# 3            234000              254600     10000000  360.0             1.0
# 4            327600                   0      7800000  360.0             1.0
#
#     Area  Area_Encoder
# 0  Urban             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Gender              367 non-null    object
#  1   Married             367 non-null    object
#  2   Dependents          367 non-null    object
#  3   Education           367 non-null    object
#  4   Education_Encoder   367 non-null    int64
#  5   Self_Employed       367 non-null    object
#  6   Applicant_Income    367 non-null    int64
#  7   Coapplicant_Income  367 non-null    int64
#  8   Loan_Amount         367 non-null    int64
#  9   Term                367 non-null    float64
#  10  Credit_History      367 non-null    float64
#  11  Area                367 non-null    object
#  12  Area_Encoder        367 non-null    int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 37.4+ KB

# %%
df.describe()
# Out:
#        Education_Encoder  Applicant_Income  Coapplicant_Income   Loan_Amount  \
# count         367.000000      3.670000e+02        3.670000e+02  3.670000e+02
# mean            0.228883      4.805599e+05        1.569578e+05  1.342779e+07
# std             0.420687      4.910685e+05        2.334232e+05  6.296143e+06
# min             0.000000      0.000000e+00        0.000000e+00  0.000000e+00
# 25%             0.000000      2.864000e+05        0.000000e+00  1.000000e+07
# 50%             0.000000      3.786000e+05        1.025000e+05  1.250000e+07
# 75%             0.000000      5.060000e+05        2.430500e+05  1.575000e+07
# max             1.000000      7.252900e+06        2.400000e+06  5.500000e+07
#
#              Term  Credit_History  Area_Encoder
# count  367.000000      367.000000    367.000000
# mean   342.822888        0.839237      0.920981
# std     64.658402        0.367814      0.824337
# min      6.000000        0.000000      0.000000
# ...

# %%
pd.options.display.float_format = '{:.0f}'.format

df.describe()
# Out:
#        Education_Encoder  Applicant_Income  Coapplicant_Income  Loan_Amount  \
# count                367               367                 367          367
# mean                   0            480560              156958     13427793
# std                    0            491069              233423      6296143
# min                    0                 0                   0            0
# 25%                    0            286400                   0     10000000
# 50%                    0            378600              102500     12500000
# 75%                    0            506000              243050     15750000
# max                    1           7252900             2400000     55000000
#
#        Term  Credit_History  Area_Encoder
# count   367             367           367
# mean    343               1             1
# std      65               0             1
# min       6               0             0
# 25%     360               1             0
# ...

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=df,x='Coapplicant_Income')
plt.tight_layout()
plt.show()

# %%
q1_CI=df['Coapplicant_Income'].quantile(0.25)
q3_CI=df['Coapplicant_Income'].quantile(0.75)
IQR_CI=q3_CI - q1_CI

# %%
min_range_CI=q1_CI-(1.5*IQR_CI)
max_range_CI=q3_CI+(1.5*IQR_CI)

min_range_CI,max_range_CI
# Out:
# (np.float64(-364575.0), np.float64(607625.0))

# %%
df
# Out:
#     Gender Married Dependents     Education  Education_Encoder Self_Employed  \
# 0     Male     Yes          0      Graduate                  0            No
# 1     Male     Yes          1      Graduate                  0            No
# 2     Male     Yes          2      Graduate                  0            No
# 3     Male     Yes          2      Graduate                  0            No
# 4     Male      No          0  Not Graduate                  1            No
# ..     ...     ...        ...           ...                ...           ...
# 362   Male     Yes         3+  Not Graduate                  1           Yes
# 363   Male     Yes          0      Graduate                  0            No
# 364   Male      No          0      Graduate                  0            No
# 365   Male     Yes          0      Graduate                  0            No
# 366   Male      No          0      Graduate                  0           Yes
#
# ...

# %% [markdown]
# **New DataFrame**

# %%
new_df=df[(df['Coapplicant_Income']<=max_range_CI) & (df['Coapplicant_Income']>=min_range_CI)]
new_df
# Out:
#     Gender Married Dependents     Education  Education_Encoder Self_Employed  \
# 0     Male     Yes          0      Graduate                  0            No
# 1     Male     Yes          1      Graduate                  0            No
# 2     Male     Yes          2      Graduate                  0            No
# 3     Male     Yes          2      Graduate                  0            No
# 4     Male      No          0  Not Graduate                  1            No
# ..     ...     ...        ...           ...                ...           ...
# 362   Male     Yes         3+  Not Graduate                  1           Yes
# 363   Male     Yes          0      Graduate                  0            No
# 364   Male      No          0      Graduate                  0            No
# 365   Male     Yes          0      Graduate                  0            No
# 366   Male      No          0      Graduate                  0           Yes
#
# ...

# %%
sns.boxplot(data=new_df,x='Coapplicant_Income')
# Out:
# <Axes: xlabel='Coapplicant_Income'>

# %%
numeric_data=new_df.select_dtypes(include='number')

plt.figure(figsize=(10,6))
sns.boxplot(data=numeric_data)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Set the OUTLIER OF LOAN AMOUNT**

# %%
q1_Loan=df['Loan_Amount'].quantile(0.25)
q3_Loan=df['Loan_Amount'].quantile(0.75)
q1_Loan,q3_Loan
# Out:
# (np.float64(10000000.0), np.float64(15750000.0))

# %%
IQR_Loan=q3_Loan - q1_Loan

# %%
min_range_Loan=q1_Loan-(1.5*IQR_Loan)
max_range_Loan=q3_Loan+(1.5*IQR_Loan)
min_range_Loan,max_range_Loan
# Out:
# (np.float64(1375000.0), np.float64(24375000.0))

# %%
df[(df['Loan_Amount']>=max_range_Loan) | (df['Loan_Amount']<=min_range_Loan)]              #  Outliers in Loan Data
# Out:
#      Gender Married Dependents     Education  Education_Encoder Self_Employed  \
# 8      Male     Yes          2      Graduate                  0            No
# 18     Male     Yes          0      Graduate                  0            No
# 24     Male     Yes          0      Graduate                  0            No
# 27     Male     Yes          0      Graduate                  0            No
# 78     Male     Yes          1      Graduate                  0            No
# 81     Male     Yes         3+      Graduate                  0            No
# 83     Male     Yes          0      Graduate                  0            No
# 91     Male     Yes         3+      Graduate                  0            No
# 96     Male     Yes          1      Graduate                  0            No
# 101  Female     Yes          0      Graduate                  0            No
# 124  Female      No          0      Graduate                  0            No
# ...

# %%
df[(df['Loan_Amount']>=max_range_Loan) | (df['Loan_Amount']<=min_range_Loan)].shape
# Out:
# (23, 13)

# %%
new_df=df[((df['Coapplicant_Income']<=max_range_CI) & (df['Coapplicant_Income']>=min_range_CI)) & ((df['Loan_Amount']<=max_range_Loan) & (df['Loan_Amount']>=min_range_Loan))]
new_df
# Out:
#     Gender Married Dependents     Education  Education_Encoder Self_Employed  \
# 0     Male     Yes          0      Graduate                  0            No
# 1     Male     Yes          1      Graduate                  0            No
# 2     Male     Yes          2      Graduate                  0            No
# 3     Male     Yes          2      Graduate                  0            No
# 4     Male      No          0  Not Graduate                  1            No
# ..     ...     ...        ...           ...                ...           ...
# 362   Male     Yes         3+  Not Graduate                  1           Yes
# 363   Male     Yes          0      Graduate                  0            No
# 364   Male      No          0      Graduate                  0            No
# 365   Male     Yes          0      Graduate                  0            No
# 366   Male      No          0      Graduate                  0           Yes
#
# ...

# %%
plt.xticks(rotation=90)
sns.boxplot(data=new_df)
# Out:
# <Axes: >

# %% [markdown]
# **Direct Method Outlier Removal / Z Score**

# %%
min_r=df['Loan_Amount'].mean() - (3*df['Loan_Amount'].std())
max_r=df['Loan_Amount'].mean() + (3*df['Loan_Amount'].std())
min_r,max_r
# Out:
# (np.float64(-5460634.788255604), np.float64(32316220.619318277))

# %%
new_data = df[(df['Loan_Amount'] >= max_r) | (df['Loan_Amount'] <= min_r)]
new_data
# Out:
#      Gender Married Dependents Education  Education_Encoder Self_Employed  \
# 81     Male     Yes         3+  Graduate                  0            No
# 91     Male     Yes         3+  Graduate                  0            No
# 143    Male     Yes          0  Graduate                  0           Yes
# 189    Male     Yes          2  Graduate                  0            No
# 194    Male     Yes          1  Graduate                  0            No
# 284  Female     Yes          2  Graduate                  0            No
#
#      Applicant_Income  Coapplicant_Income  Loan_Amount  Term  Credit_History  \
# 81            7252900                   0     36000000   360               1
# 91            1351800                   0     39000000   360               1
# 143           3200000                   0     55000000   360               1
# 189            787400              396700     33600000   360               1
# ...

# %% [markdown]
# Z Score = data - data.mean() / data.std()
#
#
# data   Real Data
#
# data>-3

# %%
new_df['Applicant_Income'].value_counts().sort_index(ascending=False)
# Out:
# Applicant_Income
# 2916700    1
# 2479700    1
# 1884000    1
# 1600000    1
# 1531200    1
#           ..
# 117300     1
# 114100     1
# 72400      1
# 57000      1
# 0          1
# Name: count, Length: 291, dtype: int64

# %%
sns.boxplot(data=new_df, x='Applicant_Income')
# Out:
# <Axes: xlabel='Applicant_Income'>

# %%
z_score=(new_df['Applicant_Income']-new_df['Applicant_Income'].mean())/new_df['Applicant_Income'].std()
outliers_zscore=(z_score>3 ) | (z_score <-3)
out=new_df[outliers_zscore]
out
# Out:
#      Gender Married Dependents Education  Education_Encoder Self_Employed  \
# 145  Female      No          0  Graduate                  0            No
# 179    Male     Yes         3+  Graduate                  0            No
# 263    Male     Yes          1  Graduate                  0            No
# 272    Male      No          1  Graduate                  0            No
# 279    Male      No          0  Graduate                  0            No
# 302  Female      No          0  Graduate                  0           Yes
# 323    Male      No          1  Graduate                  0            No
#
#      Applicant_Income  Coapplicant_Income  Loan_Amount  Term  Credit_History  \
# 145           1294100                   0     15000000   300               1
# 179           1531200                   0     18700000   360               1
# 263           1884000                   0     23400000   360               1
# ...

# %%
df.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Education_Encoder     0
# Self_Employed         0
# Applicant_Income      0
# Coapplicant_Income    0
# Loan_Amount           0
# Term                  0
# Credit_History        0
# Area                  0
# Area_Encoder          0
# dtype: int64
