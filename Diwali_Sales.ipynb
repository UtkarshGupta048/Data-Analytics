# %% [markdown]
# <a href="https://colab.research.google.com/github/UtkarshGupta048/Data-Analytics/blob/main/Diwali_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ff4b76a5-4954-4b5c-b891-3e5e4aa2c1b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff4b76a5-4954-4b5c-b891-3e5e4aa2c1b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("Diwali_Sales_Data.csv", encoding='cp1252')

# %%
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(["Status","unnamed1"], axis=1, inplace=True)

# %%
df.head(5)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
mean_val = df['Amount'].mean()
median_val = df['Amount'].median()
mode_val = df['Amount'].mode()[0]
print(mean_val)
print(median_val)
print(mode_val)
# Out:
# 9453.610857727557
# 8109.0
# 7907.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df['Amount']=df['Amount'].fillna(df['Amount'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11251 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.head(5)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.countplot(x='Gender', data=df , hue='Marital_Status')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sm=df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

# %%
sm
# Out:
#   Gender        Amount
# 0      F  7.443039e+07
# 1      M  3.193218e+07

# %%
sns.barplot(x='Gender',y='Amount',data=sm)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
df.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western  Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3  23934.0

# %%
plt.figure(figsize=(4,4))
ax=sns.countplot(data=df, x="Age Group", hue='Gender')


for bars in ax.containers:
  ax.bar_label(bars)
plt.tight_layout()
plt.show()

# %%
df.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western  Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3  23934.0

# %%
total_sales=df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Age Group' , ascending=True)
# total_sales

# Disable scientific notation
pd.set_option('display.float_format', '{:,.0f}'.format)

# Now display your DataFrame
print(total_sales)
# Out:
#   Age Group     Amount
# 0      0-17  2,699,653
# 1     18-25 17,240,732
# 2     26-35 42,632,351
# 3     36-45 22,173,356
# 4     46-50  9,245,658
# 5     51-55  8,280,384
# 6       55+  4,090,441

# %%
ay=sns.barplot(data=total_sales, x='Age Group', y='Amount')
# pd.set_option('display.float_format','{:,.0f}'.format)
for bars in ay.containers:
  ay.bar_label(bars, labels=[f'{v:.0f}' for v in bars.datavalues])

# %%
ts=df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
ts
# Out:
#   Age Group     Amount
# 2     26-35 42,632,351
# 3     36-45 22,173,356
# 1     18-25 17,240,732
# 4     46-50  9,245,658
# 5     51-55  8,280,384
# 6       55+  4,090,441
# 0      0-17  2,699,653

# %%
sns.barplot(data=ts, x='Age Group' , y='Amount')

plt.show()

# %%
df.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders  Amount
# 0     Maharashtra   Western  Healthcare             Auto       1  23,952
# 1  Andhra Pradesh  Southern        Govt             Auto       3  23,934

# %%
total_order=df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).reset_index(drop=True)
top_ten_states=total_order.head(10)

# %%
top_ten_states
# Out:
#               State  Orders
# 0     Uttar Pradesh    4813
# 1       Maharashtra    3811
# 2         Karnataka    3241
# 3             Delhi    2744
# 4    Madhya Pradesh    2259
# 5    Andhra Pradesh    2054
# 6  Himachal Pradesh    1568
# 7            Kerala    1137
# 8           Haryana    1109
# 9           Gujarat    1070

# %%
palette= sns.color_palette('husl', len(top_ten_states))
plt.figure(figsize=(8,6))
sns.barplot(data=top_ten_states, x='State', y='Orders', palette=palette)
plt.xticks(rotation=90)
plt.title("Top Ten Sales States")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3789732400.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_ten_states, x='State', y='Orders', palette=palette)

# %%
palette=sns.color_palette('deep')
sns.barplot(data=top_ten_states, y='State', x='Orders',palette=palette,hue='State')
# plt.xticks(rotation=90)
plt.title("Top Ten Sales States")
plt.show()

# %%
df.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders  Amount
# 0     Maharashtra   Western  Healthcare             Auto       1  23,952
# 1  Andhra Pradesh  Southern        Govt             Auto       3  23,934

# %%
sns.countplot(data=df,x='Marital_Status',hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
tot_order_by_occupation=df.groupby(['Occupation'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).reset_index(drop=True)
tot_order_by_occupation
# Out:
#          Occupation  Orders
# 0         IT Sector    4010
# 1        Healthcare    3455
# 2          Aviation    3215
# 3           Banking    2819
# 4              Govt    2155
# 5       Hospitality    1746
# 6             Media    1596
# 7        Automobile    1373
# 8            Lawyer    1344
# 9          Chemical    1310
# 10           Retail    1270
# 11  Food Processing    1073
# 12     Construction    1025
# 13          Textile     894
# 14      Agriculture     722

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=tot_order_by_occupation,x='Occupation',y='Orders',palette=palette)
plt.xticks(rotation=90)
plt.title('Total Order on the Basis of Occupation')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4134251953.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tot_order_by_occupation,x='Occupation',y='Orders',palette=palette)
# /tmp/ipython-input-4134251953.py:2: UserWarning:
# The palette list has fewer values (10) than needed (15) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(data=tot_order_by_occupation,x='Occupation',y='Orders',palette=palette)

# %%
df.head(5)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23,952
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23,934
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23,924
# 3       Karnataka  Southern     Construction             Auto       2  23,912
# 4         Gujarat   Western  Food Processing             Auto       2  23,877

# %%
Max_by_order_id=df.groupby(['Product_ID'],as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).reset_index(drop=True).head(10)
Max_by_order_id
# Out:
#   Product_ID  Orders
# 0  P00265242     127
# 1  P00110942     116
# 2  P00237542      91
# 3  P00184942      82
# 4  P00114942      79
# 5  P00025442      79
# 6  P00117942      76
# 7  P00145042      76
# 8  P00044442      75
# 9  P00110842      74

# %%
plt.figure(figsize=(14,5))
sns.barplot(data=Max_by_order_id,x='Product_ID',y='Orders',palette=palette)
plt.title("Top 10 Order on the basis of Product ID")
# plt.xticks(rotation=15)
plt.show()
# Out:
# /tmp/ipython-input-1874075783.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=Max_by_order_id,x='Product_ID',y='Orders',palette=palette)
