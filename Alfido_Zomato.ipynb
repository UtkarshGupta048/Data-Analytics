# %% [markdown]
# <a href="https://colab.research.google.com/github/UtkarshGupta048/Data-Analytics/blob/main/Alfido_Zomato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-fb1caedc-c82c-4993-ba56-f4ba43dd89aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb1caedc-c82c-4993-ba56-f4ba43dd89aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('zomato.csv')

# %%
pd=data.copy()

# %%
df.head(15)
# Out:
#                                               address  \
# 0   942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1   2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2   1112, Next to KIMS Medical College, 17th Cross...
# 3   1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4   10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# 5   37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...
# 6   19/1, New Timberyard Layout, Beside Satellite ...
# 7   2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
# 8   1, 30th Main Road, 3rd Stage, Banashankari, Ba...
# 9    things tend to get smokey due to the sizzlers...
# 10  2470, 21 Main Road, 25th Cross, Banashankari, ...
# 11  12,29 Near PES University Back Gate, D'Souza N...
# 12  941, 3rd FLOOR, 21st Main, 22nd Cross, Banasha...
# 13      6th Block, 3rd Stage, Banashankari, Bangalore
# 14  111, Sapphire Toys Building, 100 Feet Ring Roa...
#
#                                                  name   online_order  \
# ...

# %%
df.shape
# Out:
# (56236, 13)

# %%
df.isnull().sum()
# Out:
# address                            1
# name                               0
# online_order                       3
# book_table                     56236
# rate                           56236
# votes                          56236
# phone                          56236
# location                       56236
# rest_type                      56236
# dish_liked                     56236
# cuisines                       56236
# approx_cost(for two people)    56236
# listed_in(type)                56236
# dtype: int64

# %%
df.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table rate votes phone location rest_type dish_liked  \
# 0          Yes        NaN  NaN   NaN   NaN      NaN       NaN        NaN
# 1          Yes        NaN  NaN   NaN   NaN      NaN       NaN        NaN
# 2          Yes        NaN  NaN   NaN   NaN      NaN       NaN        NaN
# 3           No        NaN  NaN   NaN   NaN      NaN       NaN        NaN
# 4           No        NaN  NaN   NaN   NaN      NaN       NaN        NaN
#
#   cuisines approx_cost(for two people) listed_in(type)
# ...
